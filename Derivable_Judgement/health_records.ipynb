# %% [markdown]
# ## Part B - Data Analysis & Testing Tasks :

# %%
import pandas as pd 
import numpy as np 
import scipy.stats as stats 
from scipy.stats import chi2_contingency

df = pd.read_csv('health_records_dataset.csv')
df
# Out:
#                                 record_id age_group  age  weight gender  \
# 0    96fe6d81-76e2-4eb8-ae23-17644d83bb4a       60+   69      51   Male
# 1    4364c689-5f1f-42b8-ab54-c269ad0b39d4     26-35   32      52   Male
# 2    2c8a74ed-5b4b-4c47-b0d6-7f26561afd77       60+   78      98   Male
# 3    681db5e9-8e70-4182-a27a-48ec5b9f04f5     36-45   38      86  Other
# 4    098ae97e-089a-486f-be0f-b0fc5bdf1e56     36-45   41      98   Male
# ..                                    ...       ...  ...     ...    ...
# 145  e4c5830e-cdf4-46be-8dc4-37dc487532f8       60+   79      66   Male
# 146  ba77154b-15f6-4ecd-8f01-9e881c7999f1       60+   75      82   Male
# 147  3954ef3f-4579-449c-a04e-5f3432653dd8       60+   69      97   Male
# 148  b82ff5ab-5898-45e1-97ac-81e4bd0740a2     26-35   29      61   Male
# 149  a7cdac9e-2b0f-476a-8806-d3a7b17baf65     46-60   56     108   Male
#
#     region smoking_status exercise_frequency   bmi  blood_pressure  diabetes  \
# ...

# %% [markdown]
# ## Hypothesis Testing

# %%
print("Hypothesis 1:")
print("H0: Smoking has no effect on Diabetes prevalence")
print("H1: Smoking affects Diabetes prevalence")

print("\nHypothesis 2:")
print("H0: The mean BMI of Smokers and Non-Smokers is equal")
print("H1: The mean BMI of Smokers and Non-Smokers is different")
# Out:
# Hypothesis 1:
# H0: Smoking has no effect on Diabetes prevalence
# H1: Smoking affects Diabetes prevalence
#
# Hypothesis 2:
# H0: The mean BMI of Smokers and Non-Smokers is equal
# H1: The mean BMI of Smokers and Non-Smokers is different

# %% [markdown]
# ## Confidence Interval

# %%
def confidence_interval(data):
    mean = np.mean(data)
    ci = stats.t.interval(0.95, len(data)-1, loc=mean, scale=stats.sem(data))
    return mean, ci

# Age CI
age_mean, age_ci = confidence_interval(df['age'])

# Weight CI
weight_mean, weight_ci = confidence_interval(df['weight'])

print("\nAge Mean:", age_mean)
print("Age 95% CI:", age_ci)

print("\nWeight Mean:", weight_mean)
print("Weight 95% CI:", weight_ci)
# Out:
# Age Mean: 51.56666666666667
# Age 95% CI: (np.float64(48.24017758302942), np.float64(54.89315575030392))
#
# Weight Mean: 79.08666666666667
# Weight 95% CI: (np.float64(76.1409050500516), np.float64(82.03242828328175))

# %% [markdown]
# # T-test (Critical Value + P-value)

# %%
group1 = df[df['smoking_status'] == "Smoker"]['bmi']
group2 = df[df['smoking_status'] == "Non-Smoker"]['bmi']

t_stat, p_val = stats.ttest_ind(group1, group2, nan_policy='omit')

alpha = 0.05
dfree = len(group1) + len(group2) - 2
critical_value = stats.t.ppf(1 - alpha/2, dfree)

print("\nT-Test Results:")
print("t-statistic:", t_stat)
print("p-value:", p_val)
print("critical value:", critical_value)

if p_val < 0.05:
    print("Reject H0")
else:
    print("Fail to Reject H0")
# Out:
# T-Test Results:
# t-statistic: 0.2920775419851523
# p-value: 0.7707825293790771
# critical value: 1.9819674897364823
# Fail to Reject H0

# %% [markdown]
# # Z-test

# %%
mean_age = df['age'].mean()
std_age = df['age'].std()
n = len(df)

z = (mean_age - 30) / (std_age / np.sqrt(n))

print("\nZ-Test Value:", z)

if abs(z) > 1.96:
    print("Reject H0")
else:
    print("Fail to Reject H0")
# Out:
# Z-Test Value: 12.811109990346468
# Reject H0

# %% [markdown]
# ## Chi-Square Test of Independence

# %%
table = pd.crosstab(df['smoking_status'], df['diabetes'])

chi2_stat, p_value, dof, expected = chi2_contingency(table)

print("Chi-Square Statistic:", chi2_stat)
print("Degrees of Freedom:", dof)
print("P-Value:", p_value)

alpha = 0.05

if p_value < alpha:
    print("Reject H0")
else:
    print("Fail to Reject H0")
# Out:
# Chi-Square Statistic: 4.6635741307872465
# Degrees of Freedom: 2
# P-Value: 0.09712202849643768
# Fail to Reject H0

# %% [markdown]
# ## ANOVA

# %%
groups = [group['diabetes'].values
          for name, group in df.groupby('age_group', observed=False)]
f_stat, p_val = stats.f_oneway(*groups)

print("\nANOVA Test:")
print("F-stat:", f_stat)
print("p-value:", p_val)

if p_val < 0.05:
    print("Reject H0")
else:
    print("Fail to Reject H0")
# Out:
# ANOVA Test:
# F-stat: 1.122309724554227
# p-value: 0.3483424702389578
# Fail to Reject H0

# %% [markdown]
# ## Covariance and Correlation

# %%
# Covariance
covariance = df['age'].cov(df['bmi'])

# Correlation
correlation = df['age'].corr(df['bmi'])

print("Covariance between Age and BMI:", covariance)
print("Correlation between Age and BMI:", correlation)
# Out:
# Covariance between Age and BMI: -5.300425055928414
# Correlation between Age and BMI: -0.0567333595104769

# %% [markdown]
# ## Summary

# %%
print("T-Test: Fail to Reject H₀")
print("Z-Test: Reject H₀")
print("Chi-Square Test: Fail to Reject H₀")
print("ANOVA Test: Fail to Reject H₀")
# Out:
# T-Test: Fail to Reject H₀
# Z-Test: Reject H₀
# Chi-Square Test: Fail to Reject H₀
# ANOVA Test: Fail to Reject H₀
